# %%
def calculate_bmi(weightKG, heightM):
	if heightM <= 0:
		raise ValueError("Height must be greater than zero.")
	bmi = weightKG / (heightM ** 2)
	return round(bmi, 2)

print(f'BMI: {calculate_bmi(50, 2.75)}')
# Out:
# BMI: 6.61

# %%
a = 3
b = a * 2
b
# Out:
# 6
